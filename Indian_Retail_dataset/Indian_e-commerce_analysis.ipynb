# %% [markdown]
# <a href="https://colab.research.google.com/github/Clinda02/E-commerce_dataset_analysis/blob/main/Indian_Retail_dataset/Indian_e-commerce_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # E-Commerce Data 분석

# %% [markdown]
# * 데이터 출처 : [Kaggle의 E-commerce 데이터셋](https://www.kaggle.com/datasets/benroshan/ecommerce-data?select=List+of+Orders.csv)
# *  데이터 개요 : 테이블 2개과 칼럼 11개, 데이터 로우 수 2,060 건.
#   - List of Orders : 주문 데이터. 주문ID, 주문날짜, 고객명, 도시 등 지역 정보.
#   - Order Details : 주문 상세 데이터. 주문ID, 판매가격, 수익, 수량, 카테고리, 세부 카테고리 정보.

# %% [markdown]
# # (1) 데이터 로드 및 확인

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

Olist = pd.read_csv('/content/data/List of Orders.csv')
Detail = pd.read_csv('/content/data/Order Details.csv')

print("Olist :")
display(Olist.head())
print("Detail :")
display(Detail.head())
# Out:
# Olist :
#   Order ID  Order Date CustomerName           State       City
# 0  B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2  B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4  B-25605  05-04-2018      Kasheen     West Bengal    Kolkata
# Detail :
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0   -12.0         5     Clothing             Stole
# 2  B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0  -111.0         2  Electronics            Phones

# %%
Olist.info(), Detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      500 non-null    object
#  1   Order Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 22.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   float64
#  2   Profit        1500 non-null   float64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 70.4+ KB
# ...

# %%
print(f"Olist 데이터: {Olist.shape}")
print(f"Detail 데이터: {Detail.shape}")
# Out:
# Olist 데이터: (560, 5)
# Detail 데이터: (1500, 6)

# %%
Detail[Detail['Profit']<0].shape  # 환불 사례로 추측
# Out:
# (503, 6)

# %%
Detail[Detail['Amount']>0].shape
# Out:
# (1500, 6)

# %% [markdown]
# # (2) 전처리

# %%
# Order ID의 결측치 확인
Olist[Olist['Order ID'].isna()]
# Out:
#     Order ID Order Date CustomerName State City
# 500      NaN        NaN          NaN   NaN  NaN
# 501      NaN        NaN          NaN   NaN  NaN
# 502      NaN        NaN          NaN   NaN  NaN
# 503      NaN        NaN          NaN   NaN  NaN
# 504      NaN        NaN          NaN   NaN  NaN
# 505      NaN        NaN          NaN   NaN  NaN
# 506      NaN        NaN          NaN   NaN  NaN
# 507      NaN        NaN          NaN   NaN  NaN
# 508      NaN        NaN          NaN   NaN  NaN
# 509      NaN        NaN          NaN   NaN  NaN
# 510      NaN        NaN          NaN   NaN  NaN
# 511      NaN        NaN          NaN   NaN  NaN
# 512      NaN        NaN          NaN   NaN  NaN
# 513      NaN        NaN          NaN   NaN  NaN
# 514      NaN        NaN          NaN   NaN  NaN
# 515      NaN        NaN          NaN   NaN  NaN
# 516      NaN        NaN          NaN   NaN  NaN
# 517      NaN        NaN          NaN   NaN  NaN
# 518      NaN        NaN          NaN   NaN  NaN
# ...

# %%
# 각 컬럼의 결측치 확인
Olist[Olist['Order ID'].isna()].isnull().sum()
# Out:
# Order ID        60
# Order Date      60
# CustomerName    60
# State           60
# City            60
# dtype: int64

# %%
# 결측치 제거
Olist = Olist[Olist['Order ID'].isna()==False]
Olist.shape
# Out:
# (500, 5)

# %%
# Olist, Detail 데이터 병합
data = Olist.merge(Detail, on = 'Order ID')

# %%
data.shape
# Out:
# (1500, 10)

# %%
# merge 후 데이터 누락 및 중복 확인
print(f"Olist의 'Order ID' 개수 : {len(Olist['Order ID'].unique())}")
print(f"data의 'Order ID' 개수 : {len(data['Order ID'].unique())}")
print(f"Detail의 'Order ID' 개수 : {len(Detail['Order ID'].unique())}")
# Out:
# Olist의 'Order ID' 개수 : 500
# data의 'Order ID' 개수 : 500
# Detail의 'Order ID' 개수 : 500

# %%
# 결측치 확인
data.isnull().values.any()
# Out:
# False

# %%
data.head()
# Out:
#   Order ID  Order Date CustomerName        State       City  Amount  Profit  \
# 0  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad  1275.0 -1148.0
# 1  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad    66.0   -12.0
# 2  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad     8.0    -2.0
# 3  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad    80.0   -56.0
# 4  B-25602  01-04-2018        Pearl  Maharashtra       Pune   168.0  -111.0
#
#    Quantity     Category      Sub-Category
# 0         7    Furniture         Bookcases
# 1         5     Clothing             Stole
# 2         3     Clothing       Hankerchief
# 3         4  Electronics  Electronic Games
# 4         2  Electronics            Phones

# %%
# 날짜 변환
data['Order Date'] = pd.to_datetime(data['Order Date'], format = '%d-%m-%Y')

# %%
# 주문 시작일, 최근 주문일 조회
data['Order Date'].min(), data['Order Date'].max()
# Out:
# (Timestamp('2018-04-01 00:00:00'), Timestamp('2019-03-31 00:00:00'))

# %%
# 연, 월, 연월 칼럼 추가
data['year'] = data['Order Date'].dt.year
data['month'] = data['Order Date'].dt.month
data['yearmonth'] = data['Order Date'].astype('str').str.slice(0,7)

# %%
data.head(1)
# Out:
#   Order ID Order Date CustomerName    State       City  Amount  Profit  \
# 0  B-25601 2018-04-01       Bharat  Gujarat  Ahmedabad  1275.0 -1148.0
#
#    Quantity   Category Sub-Category  year  month yearmonth
# 0         7  Furniture    Bookcases  2018      4   2018-04

# %% [markdown]
# # (3) plotly를 이용한 EDA 시각화

# %%
# 라이브러리 임포트
import plotly.express as px

# %%
# 연월별 전체 주문수량 집계
df = data.groupby('yearmonth').agg({'Quantity' : 'sum'}).reset_index()
df
# Out:
#    yearmonth  Quantity
# 0    2018-04       389
# 1    2018-05       423
# 2    2018-06       369
# 3    2018-07       240
# 4    2018-08       446
# 5    2018-09       331
# 6    2018-10       419
# 7    2018-11       578
# 8    2018-12       412
# 9    2019-01       745
# 10   2019-02       512
# 11   2019-03       751

# %% [markdown]
# ### Line 그래프 그리기

# %%
# 연월별 전체 주문수량 라인그래프 생성
fig1 = px.line(df, x='yearmonth', y="Quantity", title='Sales Quantity by month')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 연월별 전체 판매금액(매출) 집계 및 시각화
df2 = data.groupby('yearmonth').agg({'Amount' : 'sum'}).reset_index()
fig2 = px.line(df2, x='yearmonth', y="Amount", title='Sales Amount by month')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Bar 그래프 그리기

# %%
# 카테고리별 판매수량 집계
df3 = data.pivot_table(index = 'Category', values=['Quantity'], aggfunc = 'sum').reset_index()
df3
# Out:
#       Category  Quantity
# 0     Clothing      3516
# 1  Electronics      1154
# 2    Furniture       945

# %%
# 카테고리별 판매수량 바그래프 생성
fig3 = px.bar(df3, x = 'Category', y = 'Quantity')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 월별로 카테고리 주문수량 집계
df4 = data.pivot_table(index = ['yearmonth','Category'], values='Quantity', aggfunc = 'sum').reset_index()
df4.head()
# Out:
#   yearmonth     Category  Quantity
# 0   2018-04     Clothing       251
# 1   2018-04  Electronics        75
# 2   2018-04    Furniture        63
# 3   2018-05     Clothing       233
# 4   2018-05  Electronics       116

# %% [markdown]
# * 누적 Bar 그래프

# %%
# 월별로 카테고리 주문수량 누적그래프 생성
fig4 = px.bar(df4, x = 'yearmonth', y = 'Quantity', color = 'Category')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * 전체 주문수량이 증가하게 된 주요 요인은 **Clothing** 카테고리다.

# %% [markdown]
# ### heat map을 이용한 지역별 주력 판매상품 분석

# %%
# 지역별 세부 카테고리의 주문수량/주문금액/매출량 집계
df5 = data.pivot_table(index = ['State','Sub-Category'], values = ['Quantity', 'Amount', 'Profit'], aggfunc = 'sum').reset_index()
df5.head()
# Out:
#             State      Sub-Category  Amount  Profit  Quantity
# 0  Andhra Pradesh       Accessories   231.0    22.0         2
# 1  Andhra Pradesh         Bookcases  4581.0 -1642.0        25
# 2  Andhra Pradesh  Electronic Games   188.0  -193.0         2
# 3  Andhra Pradesh       Furnishings    57.0     7.0         3
# 4  Andhra Pradesh       Hankerchief   710.0    80.0        32

# %%
# 밀도에 따른 히트맵 생성
fig5 = px.density_heatmap(df5, x = 'State', y = 'Sub-Category', z = 'Quantity', title='Quantity heat map') # z : 밀도
fig5.show()

fig6 = px.density_heatmap(df5, x = 'State', y = 'Sub-Category', z = 'Amount', title='Amount heat map')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
